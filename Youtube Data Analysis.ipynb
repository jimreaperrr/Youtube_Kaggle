# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from glob import glob 
import json

# %%
#Loading all files to a list and assign to variables 

def files(csv_files,json_files):
    csvs = glob(csv_files)
    jsons = glob(json_files)
    #Loading files into variables
    df_list = list(map(lambda z: pd.read_csv(z,index_col='video_id'), csvs))
    brit, germ, can, fran, usa = list(map(lambda a: json.load(open(a,'r')), jsons))

files("data/*.csv","data/*.json")

# %%
df_list[4]
# Out:
#             trending_date                                              title  \
# video_id
# 2kyS6SvSYSE      17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
# 1ZAPwfrtAFY      17.14.11  The Trump Presidency: Last Week Tonight with J...
# 5qpjK5DgCt4      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
# puqaWrEC7tY      17.14.11                   Nickelback Lyrics: Real or Fake?
# d380meD0W0M      17.14.11                           I Dare You: GOING BALD!?
# gHZ1Qz0KiKM      17.14.11                              2 Weeks with iPhone X
# 39idVpFF7NQ      17.14.11          Roy Moore & Jeff Sessions Cold Open - SNL
# nc99ccSXST0      17.14.11                5 Ice Cream Gadgets put to the Test
# jr9QtXwC9vc      17.14.11  The Greatest Showman | Official Trailer 2 [HD]...
# TUmyygCMMGA      17.14.11  Why the rise of the robots won’t mean the end ...
# 9wRQljFNDW8      17.14.11  Dion Lewis' 103-Yd Kick Return TD vs. Denver! ...
# ...

# %%
df_list = list(map(lambda z: pd.read_csv(z,index_col='video_id'),
                                                             csvs))
df_list


#print([map(lambda i:  pd.read_csv(i, index_col= "video_id"), csvs)])
# Out:
# [            trending_date                                              title  \
#  video_id
#  n1WpP7iowLc      17.14.11         Eminem - Walk On Water (Audio) ft. Beyoncé
#  0dBIkQ4Mz1M      17.14.11                      PLUSH - Bad Unboxing Fan Mail
#  5qpjK5DgCt4      17.14.11  Racist Superman | Rudy Mancuso, King Bach & Le...
#  d380meD0W0M      17.14.11                           I Dare You: GOING BALD!?
#  2Vv-BfVoq4g      17.14.11        Ed Sheeran - Perfect (Official Music Video)
#  0yIWz1XEeyc      17.14.11  Jake Paul Says Alissa Violet CHEATED with LOGA...
#  _uM5kFfkhB8      17.14.11             Vanoss Superhero School - New Students
#  2kyS6SvSYSE      17.14.11                 WE WANT TO TALK ABOUT OUR MARRIAGE
#  JzCsM1vtn78      17.14.11               THE LOGANG MADE HISTORY. LOL. AGAIN.
#  43sm-QwLcx4      17.14.11  Finally Sheldon is winning an argument about t...
#  H1KBHFXm2Bg      17.14.11    21 Savage - Bank Account (Official Music Video)
# ...

# %%
pd.read_csv("../data/CAvideos.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-ad10b7dab068> in <module>()
# ----> 1 pd.read_csv("../data/CAvideos.csv")
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# ...
